# %%
import pandas as pd
import numpy as np
from sklearn.externals import joblib

# %%
df = joblib.load('raw_obentou.pkl')
df.head()
# Out:
#      datetime    y week  soldout        name  kcal remarks event  payday  \
# 0  2013-11-18   90    月        0    厚切りイカフライ   NaN     NaN   NaN     NaN
# 1  2013-11-19  101    火        1     手作りヒレカツ   NaN     NaN   NaN     NaN
# 2  2013-11-20  118    水        0  白身魚唐揚げ野菜あん   NaN     NaN   NaN     NaN
# 3  2013-11-21  120    木        1      若鶏ピリ辛焼   NaN     NaN   NaN     NaN
# 4  2013-11-22  130    金        1    ビッグメンチカツ   NaN     NaN   NaN     NaN
#
#   weather precipitation  temperature
# 0      快晴            --         19.8
# 1      快晴            --         17.0
# 2      快晴            --         15.5
# 3      快晴            --         15.2
# 4      快晴            --         16.1

# %%
df.isnull().sum()
# Out:
# datetime           0
# y                  0
# week               0
# soldout            0
# name               0
# kcal              41
# remarks          186
# event            193
# payday           197
# weather            0
# precipitation      0
# temperature        0
# dtype: int64

# %% [markdown]
# ## カラム毎に異なる値で欠損値を補完する

# %%
df = df.fillna({
    'kcal':df['kcal'].mean(),
    'remarks':'不明',
    'event':'不明',
    'payday':0.0
})
df.head()
# Out:
#      datetime    y week  soldout        name        kcal remarks event  \
# 0  2013-11-18   90    月        0    厚切りイカフライ  404.409639      不明    不明
# 1  2013-11-19  101    火        1     手作りヒレカツ  404.409639      不明    不明
# 2  2013-11-20  118    水        0  白身魚唐揚げ野菜あん  404.409639      不明    不明
# 3  2013-11-21  120    木        1      若鶏ピリ辛焼  404.409639      不明    不明
# 4  2013-11-22  130    金        1    ビッグメンチカツ  404.409639      不明    不明
#
#    payday weather precipitation  temperature
# 0     0.0      快晴            --         19.8
# 1     0.0      快晴            --         17.0
# 2     0.0      快晴            --         15.5
# 3     0.0      快晴            --         15.2
# 4     0.0      快晴            --         16.1

# %%
df.isnull().sum()
# Out:
# datetime         0
# y                0
# week             0
# soldout          0
# name             0
# kcal             0
# remarks          0
# event            0
# payday           0
# weather          0
# precipitation    0
# temperature      0
# dtype: int64
