# %%
import pandas as pd
import numpy as np

# %%
def basic_check(df):
    '''
    読み込んだデータフレームの
    ・行と列の長さ
    ・各カラムの欠損値の数
    ・各カラムのデータの型
    ・データフレームのレコード先頭から5行、末尾から5行
    を確認する
    '''
    print('行と列の長さ\n{}'.format(df.shape))
    print('-'*50)
    print('各カラムの欠損値の数\n{}'.format(df.isnull().sum()))
    print('-'*50)
    print(df.info())
    display(df.head(), df.tail())

# %%
df = pd.read_excel('文字列の長さが異なるカラムを含むテーブル.xlsx', dtype='object')
df['correct_code_id'] = ['00101', '00102', '08103', '70104', '00105', '00106', '60107', '00108', '00109', '00100']
basic_check(df)
# Out:
# 行と列の長さ
# (10, 3)
# --------------------------------------------------
# 各カラムの欠損値の数
# id                 0
# code_id            0
# correct_code_id    0
# dtype: int64
# --------------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
# id                 10 non-null object
# code_id            10 non-null object
# correct_code_id    10 non-null object
# dtypes: object(3)
# memory usage: 320.0+ bytes
# None
#   id code_id correct_code_id
# 0  1   00101           00101
# 1  2   00102           00102
# 2  3    0103           08103
# 3  4    0104           70104
# 4  5   00105           00105
#    id code_id correct_code_id
# 5   6   00106           00106
# 6   7     107           60107
# 7   8   00108           00108
# 8   9   00109           00109
# 9  10   00110           00100

# %%
df['文字の長さ'] = df['code_id'].map(lambda x: len(x))
df
# Out:
#    id code_id correct_code_id  文字の長さ
# 0   1   00101           00101      5
# 1   2   00102           00102      5
# 2   3    0103           08103      4
# 3   4    0104           70104      4
# 4   5   00105           00105      5
# 5   6   00106           00106      5
# 6   7     107           60107      3
# 7   8   00108           00108      5
# 8   9   00109           00109      5
# 9  10   00110           00100      5

# %%
def replace_strings_by_string_length(df, threshold=5):
    '''文字の長さが閾値未満の要素のみ別のカラムの要素に置き換える関数'''
    
    if df['文字の長さ'] < threshold:
        df['new_code_id'] = df['correct_code_id']
    else:
        df['new_code_id'] = df['code_id']
    
    return df

# %%
df = df.apply(replace_strings_by_string_length, axis=1)
df
# Out:
#    id code_id correct_code_id  文字の長さ new_code_id
# 0   1   00101           00101      5       00101
# 1   2   00102           00102      5       00102
# 2   3    0103           08103      4       08103
# 3   4    0104           70104      4       70104
# 4   5   00105           00105      5       00105
# 5   6   00106           00106      5       00106
# 6   7     107           60107      3       60107
# 7   8   00108           00108      5       00108
# 8   9   00109           00109      5       00109
# 9  10   00110           00100      5       00110

# %%
df = df.drop(['code_id', 'correct_code_id', '文字の長さ'], axis=1).rename(columns={'new_code_id':'code_id'})
df
# Out:
#    id code_id
# 0   1   00101
# 1   2   00102
# 2   3   08103
# 3   4   70104
# 4   5   00105
# 5   6   00106
# 6   7   60107
# 7   8   00108
# 8   9   00109
# 9  10   00110
