# %%
import sys,os
import gc
from pathlib import Path
import glob
import re
import pickle
import warnings

import pandas as pd
import numpy as np

from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
pd.options.display.max_rows = 1000
pd.options.display.max_columns = 1000
plt.rcParams["font.size"] = 16
plt.rcParams['figure.figsize']=[16,9]
plt.rcParams['font.family']= 'TakaoPGothic'
pd.options.display.float_format = '{:.13g}'.format
warnings.filterwarnings('ignore')

# %%
# 引数に「sheet_name=None」を指定してすべてのシートを読み込む
all_sheet_df = pd.read_excel('data/toeic_words.xlsx', sheet_name=None)

all_sheet_df
# Out:
# OrderedDict([('part1',             単語      意味
#               0     beverage     飲み物
#               1  get changed  服を着替える
#               2      shelves       棚
#               3        shelf       棚
#               4       ladder     はしご),
#              ('part3',                        単語                 意味
#               0        an attached file             添付ファイル
#               1   an instruction manual              取扱説明書
#               2           specification             詳細、仕様書
#               3      Could you see if ~  ～かどうか確認していただけませんか
#               4                 or else            そうでなければ
#               5            in that case             その場合には
#               6            considerably                かなり
#               7              beforehand                事前に
#               8                brochure             パンフレット
#               9          island hopping                島巡り
#               10          complimentary                無料の
# ...

# %%
p1_df = all_sheet_df['part1']

p1_df
# Out:
#             単語      意味
# 0     beverage     飲み物
# 1  get changed  服を着替える
# 2      shelves       棚
# 3        shelf       棚
# 4       ladder     はしご

# %%
p3_df = all_sheet_df['part3']

p3_df
# Out:
#                        単語                 意味
# 0        an attached file             添付ファイル
# 1   an instruction manual              取扱説明書
# 2           specification             詳細、仕様書
# 3      Could you see if ~  ～かどうか確認していただけませんか
# 4                 or else            そうでなければ
# 5            in that case             その場合には
# 6            considerably                かなり
# 7              beforehand                事前に
# 8                brochure             パンフレット
# 9          island hopping                島巡り
# 10          complimentary                無料の
# 11     settle the payment             支払いを行う
# 12             a loaf of～     ひとかたまりの～(パンなど)
# 13             wholegrain               全粒粉の
# 14             on special                特売の
# 15              take down            〜を取り下げる
# 16                   run～               ～を行う
# 17               pamphlet             パンフレット

# %% [markdown]
# 参考
#
# https://note.nkmk.me/python-pandas-read-excel/
