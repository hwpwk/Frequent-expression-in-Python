# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### データ読み込み時にカラムを絞る
# usecols=['xx', 'yy']を引数に与える

# %%
df = pd.read_csv('train.csv', usecols=['name', 'kcal', 'y', 'soldout'])
df.head()
# Out:
#      y  soldout        name  kcal
# 0   90        0    厚切りイカフライ   NaN
# 1  101        1     手作りヒレカツ   NaN
# 2  118        0  白身魚唐揚げ野菜あん   NaN
# 3  120        1      若鶏ピリ辛焼   NaN
# 4  130        1    ビッグメンチカツ   NaN

# %% [markdown]
# ## 欠損値が1つでも含むレコードを抽出

# %%
df1 = df[df.isnull().any(axis=1)]
df1
# Out:
#        y  soldout              name  kcal
# 0     90        0          厚切りイカフライ   NaN
# 1    101        1           手作りヒレカツ   NaN
# 2    118        0        白身魚唐揚げ野菜あん   NaN
# 3    120        1            若鶏ピリ辛焼   NaN
# 4    130        1          ビッグメンチカツ   NaN
# 5    135        1              鶏の唐揚   NaN
# 6    145        0          豚のスタミナ炒め   NaN
# 7    140        1          ボローニャ風カツ   NaN
# 8    151        0             ハンバーグ   NaN
# 9    116        0     タルタルinソーセージカツ   NaN
# 10   151        1             マーボ豆腐   NaN
# 11   153        1          厚揚げ豚生姜炒め   NaN
# 12   151        1      クリームチーズ入りメンチ   NaN
# 13   171        0       鶏のカッシュナッツ炒め   NaN
# 14   134        0          手作りロースカツ   NaN
# 15   165        1        ハンバーグデミソース   NaN
# 16   155        0     やわらかロースのサムジョン   NaN
# 17   157        0              五目御飯   NaN
# 18   109        0              肉じゃが   NaN
# 19   111        1          タンドリーチキン   NaN
# 20   160        0         カキフライタルタル   NaN
# ...
