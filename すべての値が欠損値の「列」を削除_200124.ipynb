# %%
import pandas as pd
import numpy as np

# %%
path = r'C:Data/'

df = pd.read_excel(path+'アスファルト合材【会員】製造数量【速報値】_201911.xlsx', skiprows=[0,1,2,3])

# %% [markdown]
# # すべての値が欠損値の「列」を削除

# %%
df = df.dropna(axis=1, how='all')

df
# Out:
#                                                   新　規   Unnamed: 1       再　生   \
# 0    　 【北海道】 北海道   89 104      87,572     340,684  ...         NaN        NaN
# 1                                                 青　森         17.0       17.0
# 2                                                 岩　手         22.0       24.0
# 3                                                 宮　城         15.0       17.0
# 4                                                 秋　田         24.0       24.0
# 5                                                 山　形         16.0       16.0
# 6                                                 福　島         23.0       24.0
# 7                                                 東　北        117.0      122.0
# 8                                               165759         NaN   338315.0
# 9                                               128366         NaN   417050.0
# 10                                              206071         NaN   663778.0
# ...
