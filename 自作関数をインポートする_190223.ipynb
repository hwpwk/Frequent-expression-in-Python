# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## ライブラリ読み込み対象ディレクトリを追加

# %%
import sys
sys.path.append(r'C:\Users\Owner\Documents\181115\py')

# %% [markdown]
# ## パスの一覧を格納したリストを表示

# %%
import sys
display(sys.path)
# Out:
# ['',
#  'C:\\Anaconda\\python36.zip',
#  'C:\\Anaconda\\DLLs',
#  'C:\\Anaconda\\lib',
#  'C:\\Anaconda',
#  'C:\\Anaconda\\lib\\site-packages',
#  'C:\\Anaconda\\lib\\site-packages\\Babel-2.5.0-py3.6.egg',
#  'C:\\Anaconda\\lib\\site-packages\\win32',
#  'C:\\Anaconda\\lib\\site-packages\\win32\\lib',
#  'C:\\Anaconda\\lib\\site-packages\\Pythonwin',
#  'C:\\Anaconda\\lib\\site-packages\\IPython\\extensions',
#  'C:\\Users\\Owner\\.ipython',
#  'C:\\Users\\Owner\\Documents\\181115\\py']

# %% [markdown]
# # 自作関数のインポート

# %%
import my_creating_func

# %%
df = pd.read_csv('train.csv').dropna(subset=['kcal'])
my_creating_func.basic_check(df)
# Out:
# 行と列の長さ
# (166, 12)
# --------------------------------------------------
# 各カラムの欠損値の数
# datetime           0
# y                  0
# week               0
# soldout            0
# name               0
# kcal               0
# remarks          158
# event            155
# payday           158
# weather            0
# precipitation      0
# temperature        0
# dtype: int64
# --------------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 166 entries, 28 to 206
# Data columns (total 12 columns):
# datetime         166 non-null object
# y                166 non-null int64
# week             166 non-null object
# soldout          166 non-null int64
# name             166 non-null object
# kcal             166 non-null float64
# remarks          8 non-null object
# event            11 non-null object
# payday           8 non-null float64
# weather          166 non-null object
# precipitation    166 non-null object
# ...

# %% [markdown]
# # 四分位範囲の 1.5 倍未満、1.5倍超過データを外れ値として削除

# %%
df1 = my_creating_func.exclude_outliers(df, 'kcal')

my_creating_func.basic_check(df1)
# Out:
# 行と列の長さ
# (163, 12)
# --------------------------------------------------
# 各カラムの欠損値の数
# datetime           0
# y                  0
# week               0
# soldout            0
# name               0
# kcal               0
# remarks          155
# event            153
# payday           155
# weather            0
# precipitation      0
# temperature        0
# dtype: int64
# --------------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 163 entries, 28 to 206
# Data columns (total 12 columns):
# datetime         163 non-null object
# y                163 non-null int64
# week             163 non-null object
# soldout          163 non-null int64
# name             163 non-null object
# kcal             163 non-null float64
# remarks          8 non-null object
# event            10 non-null object
# payday           8 non-null float64
# weather          163 non-null object
# precipitation    163 non-null object
# ...
